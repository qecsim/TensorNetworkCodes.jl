# %% [markdown]
# # The modified surface code
# Compilation time will cause a delay for most calculations here for their first run, especially plots and
# operator weight calculations.

# %%
using Logging
using TensorNetworkCodes, TensorNetworkCodes.TNDecode, TensorNetworkCodes.TNDistance
using Qecsim, Qecsim.GenericModels

# %% [markdown]
# ## Let's change one of the seed codes in the rotated surface code
# We'll only change the central seed code

# %%
stabilizers = [[1, 3, 0, 1, 3], [3, 3, 1, 0, 1], [3, 1, 3, 1, 0], [1, 0, 3, 3, 1]]
logicals = [[1, 1, 1, 1, 1], [3, 3, 3, 3, 3]]
new_seed_code = SimpleCode("Permuted five qubit code", stabilizers, logicals)

# Let's define our new code
modified_rotated_surface_code(L) = almost_rotated_surface_code(L, new_seed_code, fill(ceil(Int,L/2), 2));

# %% [markdown]
# ## Let's find the stabilizers for a 7x7 code
# Most of them are the same as for the rotated surface code

# %%
L = 7
□ = modified_rotated_surface_code(L)
operators = □.stabilizers

for η in 1:10 # just some operators, for all use: 1:length(operators)
    display(operator_plot(□,operators[η]))
end
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...

# %% [markdown]
# ## Let's find the four weird stabilizers
# We simplify them by taking products with local stabilizers

# %%
# This one needs to be multiplied by two other stabilizers to simplify
operator_plot(□, pauli_product(operators[[44, 45, 46]]))
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...

# %%
# This next one needs to be multiplied by four stabilizers to simplify
operator_plot(□, pauli_product(operators[[20, 29, 34, 36, 37]]))
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...

# %%
# Third one
operator_plot(□, pauli_product(operators[[2, 5, 14, 20]]))
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...

# %%
# Fourth one
operator_plot(□, pauli_product(operators[[27, 11, 18]]))
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9259656985813166cx, 0.9512195121951219cy), (0.6512700737764069cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9512195121951219cx, 0.9259656985813166cy), (0.9512195121951219cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9690766550522648cx, 0.9690766550522648cy), (0.9821428571428571cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6007624465487963cx, 0.9512195121951219cy), (0.3260668217438865cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6260162601626016cx, 0.9259656985813166cy), (0.6260162601626016cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, 0.9690766550522648cy), (0.6569396051103368cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, 0.9512195121951219cy), (0.0008635697113662209cx, 0.9512195121951219cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.30081300813008127cx, 0.9259656985813166cy), (0.30081300813008127cx, 0.6512700737764069cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, 0.9690766550522648cy), (0.3317363530778165cx, 0.9821428571428571cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, 0.9512195121951219cy), (-0.3243396823211541cx, 0.9512195121951219cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6438734030197445cx, -0.9821428571428571cy), (0.6569396051103368cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.27555919451627603cx, -1.0cy), (0.0008635697113662209cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3186701509872241cx, -0.9821428571428571cy), (0.3317363530778165cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.049644057516244317cx, -1.0cy), (-0.3243396823211541cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.00653310104529619cx, -0.9821428571428571cy), (0.006533101045296186cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3748473095487646cx, -1.0cy), (-0.6495429343536744cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.3317363530778165cx, -0.9821428571428571cy), (-0.31867015098722423cx, -0.9690766550522648cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.700050561581285cx, -1.0cy), (-0.9747461863861947cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{ ...

# %% [markdown]
# ## Let's look at the code distances

# %%
□_weights = tn_operator_weights(□)
□_dist = □_weights.distance

surface = rotated_surface_code(L)
surface_weights = tn_operator_weights(surface)
surface_dist = surface_weights.distance

println("Modified code distance is $(□_dist).")
println("Rotated surface code distance is $(surface_dist).")
# Out:
# Modified code distance is 7.
# Rotated surface code distance is 7.

# %% [markdown]
# ## Degeneracy of the min-weight logical operators

# %%
□_deg = □_weights.all_operator_weights[□_dist+1] - □_weights.stabilizer_weights[□_dist+1]
println("Degeneracy of min-weight logical operators for modified code is $(□_deg).")

surface_deg = surface_weights.all_operator_weights[surface_dist+1] - 
surface_weights.stabilizer_weights[surface_dist+1]
println("For the rotated surface code it is $(surface_deg).")
# Out:
# Degeneracy of min-weight logical operators for modified code is 650.
# For the rotated surface code it is 896.

# %% [markdown]
# ## Compare error correction properties with the normal rotated surface code
# * This uses exact TN contraction to decode to get a fair comparison between the codes.
#
# * Here we look at depolarizing noise.
#
# * Current parameters below take about one minute on my laptop. (i7-7500U CPU @ 2.70GHz × 4, 8GB RAM)

# %%
ℓ = 5
qs_surf_code = QecsimTNCode(rotated_surface_code(ℓ); distance=5, label="5x5 Surface Code")
qs_mod_code = QecsimTNCode(modified_rotated_surface_code(ℓ); distance=5, label="5x5 Modified Code")

function eval_success_probabilities(code1, code2, error_probabilities, max_runs, seed=13)
    error_model, decoder = DepolarizingErrorModel(), QecsimTNDecoder()
    # success data [code1, code2]
    empirical = [(rates=Float64[], stderrs=Float64[]), (rates=Float64[], stderrs=Float64[])]
    predicted = [(rates=Float64[], stderrs=Float64[]), (rates=Float64[], stderrs=Float64[])]
    with_logger(NullLogger()) do  # disable qecsim logs
        for p in error_probabilities
            p_seed = trunc(Int, seed * p * 1000)  # different seed for each p
            for (i, code) in enumerate((code1, code2))
                data = qec_run(code, error_model, decoder, p, p_seed; max_runs=max_runs)
                esr = data[:n_success]/data[:n_run]  # empirical success rate
                push!(empirical[i].rates, esr)
                push!(empirical[i].stderrs, sqrt(esr*(1-esr)/data[:n_run]))
                psr = data[:custom_totals][1]/data[:n_run]  # predicted success rate TODO: fix
                push!(predicted[i].rates, psr)
                push!(predicted[i].stderrs, sqrt(psr*(1-psr)/data[:n_run]))  # TODO: fix
                print('.')  # progress indicator
            end
        end
        println()
    end
    return (empirical=empirical, predicted=predicted)
end

error_probabilities = [0.0,0.02,0.04,0.06,0.08,0.10,0.12,0.14,0.16,0.18,0.2]
num_iter = 1000
@time output = eval_success_probabilities(qs_surf_code, qs_mod_code, error_probabilities, num_iter);
# println(output[1][1])
# println(output[1][2])
# println(output[2][1])
# println(output[2][2])
# Out:
# ......................
#  97.375804 seconds (269.24 M allocations: 78.757 GiB, 11.21% gc time, 21.10% compilation time)

# %% [markdown]
# ## Let's plot this

# %%
success_data = output.empirical

using PyPlot
rcParams = PyPlot.PyDict(PyPlot.matplotlib."rcParams")
font0 = Dict(
    "font.size" => 16,
    "axes.labelweight" => "normal",
    "axes.labelsize" => 18,
    "xtick.labelsize" => 16,
    "ytick.labelsize" => 16,
    "legend.fontsize" => 14,
)
merge!(rcParams, font0)

x = error_probabilities
fig, ax = subplots(figsize=(10,5.5))

y = success_data[1].rates
yerr = [success_data[1].stderrs, success_data[1].stderrs]
p = ax.plot(x,y,linestyle="dashed",marker=",",color="C0",label="$(ℓ)x$(ℓ) surface code")
pe = ax.errorbar(x,y,yerr,color="C0",fmt=",",markersize=7, capsize=4, elinewidth=2)

y = success_data[2].rates
yerr = [success_data[2].stderrs, success_data[2].stderrs]
p = ax.plot(x,y,linestyle="solid",marker=",",color="C1",label="$(ℓ)x$(ℓ) modified code")
pe = ax.errorbar(x,y,yerr,color="C1",fmt=",",markersize=7, capsize=4, elinewidth=2)

ax.axis("tight")
ax.set_xlabel("Physical error probability \$p\$",fontsize=18)
ax.set_ylabel("Success rate",fontsize=18)
ax.grid(true)
legend(loc="lower left");
# plt.savefig("name.pdf", bbox_inches="tight", pad_inches=0.1)
# Out:
# Figure(PyObject <Figure size 1000x550 with 1 Axes>)
